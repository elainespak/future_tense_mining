# %%
from nltk.tokenize import sent_tokenize
from selenium import webdriver
from ast import literal_eval
import pandas as pd
import numpy as np
import requests
import nltk
import json
import time
import re

# %%
df_kospi_filing_2015_2019 = pd.read_excel('D:\\data\\finance\\financial_statements\\kr\\kospi200_2015_2019.xlsx')

# %%
# Use nltk to split sentences (works great on Korean as well)
raw_text = df_kospi_filing_2015_2019['Text']
token_text = raw_text.apply(lambda x: sent_tokenize(x))

# Use extra hand-made parser
def additional_sent_tokenize(text):
    '''
    Some bullet points, which should be taken as separate sentences,
    are not accounted for by the nltk sentence tokenizer.
    This additional tokenizer will take care of such bullet points.
    '''
    if '※' in text:
        text_list = text.split('※')
    elif '* ' in text:
        text_list = text.split('* ')
    else:
        text_list = [text]
    return text_list

additional_token_text =[]

for t in token_text:
    temp_list = []
    for sent in t:
        temp_list.append(additional_sent_tokenize(sent))
    additional_token_text.append([item for sublist in temp_list for item in sublist])

# Select relevant, proper sentences and pre-process
def clean_text(text):
    '''
    Clean the messy raw text
    1) Remove \n, 전자공시시스템 dart.fss.or.kr, Page #
    2) Remove white space before and after the input text
    '''
    text = re.sub("\\n|(전자공시시스템 dart\.fss\.or\.kr)?(\n)?(Page \d{1,2})?(?=\s)",
                  " ",
                  text)
    text = re.sub("\s\s+", " ", text).strip()
    return text

sent_text = []

for t in additional_token_text:
    relevant_sentences = []
    
    for s in t:
        if s.endswith('니다.'):
            s = clean_text(s)
            s = s.strip()
            if len(s) > 5000:
                split_txt = [s[i*len(s)//30:(i+1)*len(s)//30] for i in range(30)]
                relevant_sentences += split_txt
            if len(s) > 3000:
                split_txt = [s[i*len(s)//20:(i+1)*len(s)//20] for i in range(20)]
                relevant_sentences += split_txt
            if len(s) > 1000:
                split_txt = [s[i*len(s)//10:(i+1)*len(s)//10] for i in range(10)]
                relevant_sentences += split_txt
            else:
                relevant_sentences += [s]
            
    sent_text.append(relevant_sentences)

# Save checkpoint
df_kospi_filing_2015_2019['Relevant_Sentences'] = sent_text

# %%
df_kospi_filing_2015_2019_parsed = df_kospi_filing_2015_2019.drop(['Text'], axis=1)
df_kospi_filing_2015_2019_parsed.to_csv('kospi200_2015_2019_parsed.csv', encoding='utf-8', index=False)

# %%
df_kospi_filing_2015_2019_parsed = pd.read_csv('kospi200_2015_2019_parsed.csv', encoding='utf-8')
df_kospi_filing_2015_2019_parsed['Relevant_Sentences'] = [literal_eval(s) for s in df_kospi_filing_2015_2019_parsed['Relevant_Sentences']]

# %%
def make_sublist(text):
    batch = []
    batch_size = 5
    num_batches = int(np.ceil(len(text)/batch_size))
    for i in range(num_batches):
        batch.append(' '.join(text[batch_size*i:batch_size*(i+1)]))
    return batch

text_series_sublists = df_kospi_filing_2015_2019_parsed['Relevant_Sentences'].apply(make_sublist)

# %%
df_kospi_filing_2015_2019_parsed = pd.read_csv('kospi200_2015_2019_translated.csv', encoding='utf-8')
df_kospi_filing_2015_2019_parsed['Relevant_Sentences'] = [literal_eval(s) for s in df_kospi_filing_2015_2019_parsed['Relevant_Sentences']]
def make_sublist(text):
    batch = []
    batch_size = 5
    num_batches = int(np.ceil(len(text)/batch_size))
    for i in range(num_batches):
        batch.append(' '.join(text[batch_size*i:batch_size*(i+1)]))
    return batch

text_series_sublists = df_kospi_filing_2015_2019_parsed[df_kospi_filing_2015_2019_parsed.Translated.isnull()]['Relevant_Sentences'].apply(make_sublist)

# %%
path = "C:\\Users\\sylim2357\\Documents\\chromedriver_win32\\chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get('https://translate.google.com/#view=home&op=translate&sl=ko&tl=en')
elem = driver.find_element_by_id("source")
# df_kospi_filing_2015_2019_parsed['Translated'] = ''
for idx, text_sublist in text_series_sublists.iteritems():
    print(str(idx)+': translating')
    translated_text = []
    for text in text_sublist:
        elem.clear()
        time.sleep(np.random.randint(50,300)/101)
        elem.send_keys(text)
        status = True
        while status:
            try:
                time.sleep(np.random.randint(100,300)/101)
                translated_text.append(driver.find_element_by_class_name("tlid-translation").text)
                status = False
            except:
                status = True
    print(str(idx)+': translated')
    df_kospi_filing_2015_2019_parsed.loc[idx, 'Translated'] = ' '.join(translated_text)
    if idx % 20 == 0:
        df_kospi_filing_2015_2019_parsed.to_csv('kospi200_2015_2019_translated.csv', encoding='utf-8', index=False)
driver.close()
df_kospi_filing_2015_2019_parsed.to_csv('kospi200_2015_2019_translated.csv', encoding='utf-8', index=False)
# Out:
# 512: translating
# 512: translated
# 514: translating
# 514: translated
# 2355: translating
# 2355: translated
# 2356: translating
# 2356: translated
# 2357: translating
# 2357: translated
# 2358: translating
# 2358: translated
# 2359: translating
# 2359: translated
# 2361: translating
# 2361: translated
# 2362: translating
# 2362: translated
# 2363: translating
# 2363: translated
# 2364: translating
# 2364: translated
# 2365: translating
# 2365: translated
# 2366: translating
# 2366: translated
# 2481: translating
# 2481: translated
# 2482: translating
# 2482: translated
# 2483: translating
# 2483: translated
# 2484: translating
# 2484: translated
# 2485: translating
# 2485: translated
# 2486: translating
# 2486: translated
# 2487: translating
# 2487: translated
# 2488: translating
# 2488: translated
# 2489: translating
# 2489: translated
# 2490: translating
# 2490: translated
# 2491: translating
# 2491: translated
# 2492: translating
# 2492: translated
# 2493: translating
# 2493: translated
# 2494: translating
# 2494: translated
# 2495: translating
# 2495: translated
# 2496: translating
# 2496: translated
# 2497: translating
# 2497: translated
# 2498: translating
# 2498: translated
# 2499: translating
# 2499: translated
# 2500: translating
# 2500: translated
# 2501: translating
# 2501: translated
# 2502: translating
# 2502: translated
# 2503: translating
# 2503: translated
# 2504: translating
# 2504: translated
# 2505: translating
# 2505: translated
# 2506: translating
# 2506: translated
# 2507: translating
# 2507: translated
# 2508: translating
# 2508: translated
# 2509: translating
# 2509: translated
# 2510: translating
# 2510: translated
# 2511: translating
# 2511: translated
# 2512: translating
# 2512: translated
# 2513: translating
# 2513: translated
# 2514: translating
# 2514: translated
# 2515: translating
# 2515: translated
# 2516: translating
# 2516: translated
# 2517: translating
# 2517: translated
# 2518: translating
# 2518: translated
# 2519: translating
# 2519: translated
# 2520: translating
# 2520: translated
# 2521: translating
# 2521: translated
# 2522: translating
# 2522: translated
# 2523: translating
# 2523: translated
# 2524: translating
# 2524: translated
# 2525: translating
# 2525: translated
# 2526: translating
# 2526: translated
# 2527: translating
# 2527: translated
# 2528: translating
# 2528: translated
# 2529: translating
# 2529: translated
# 2530: translating
# 2530: translated
# 2531: translating
# 2531: translated
# 2532: translating
# 2532: translated
# 2533: translating
# 2533: translated
# 2534: translating
# 2534: translated
# 2535: translating
# 2535: translated
# 2536: translating
# 2536: translated
# 2537: translating
# 2537: translated
# 2538: translating
# 2538: translated
# 2539: translating
# 2539: translated
# 2540: translating
# 2540: translated
# 2541: translating
# 2541: translated
# 2542: translating
# 2542: translated
# 2543: translating
# 2543: translated
# 2544: translating
# 2544: translated
# 2545: translating
# 2545: translated
# 2546: translating
# 2546: translated
# 2547: translating
# 2547: translated
# 2548: translating
# 2548: translated
# 2549: translating
# 2549: translated
# 2550: translating
# 2550: translated
# 2551: translating
# 2551: translated
# 2552: translating
# 2552: translated
# 2553: translating
# 2553: translated
# 2554: translating
# 2554: translated
# 2555: translating
# 2555: translated
# 2556: translating
# 2556: translated
# 2557: translating
# 2557: translated
# 2558: translating
# 2558: translated
# 2559: translating
# 2559: translated
# 2560: translating
# 2560: translated
# 2561: translating
# 2561: translated
# 2562: translating
# 2562: translated
# 2563: translating
# 2563: translated
# 2564: translating
# 2564: translated
# 2565: translating
# 2565: translated
# 2566: translating
# 2566: translated
# 2567: translating
# 2567: translated
# 2568: translating
# 2568: translated
# 2569: translating
# 2569: translated
# 2570: translating
# 2570: translated
# 2571: translating
# 2571: translated
# 2572: translating
# 2572: translated
# 2573: translating
# 2573: translated
# 2574: translating
# 2574: translated
# 2575: translating
# 2575: translated
# 2576: translating
# 2576: translated
# 2577: translating
# 2577: translated
# 2578: translating
# 2578: translated
# 2579: translating
# 2579: translated
# 2580: translating
# 2580: translated
# 2581: translating
# 2581: translated
# 2582: translating
# 2582: translated
# 2583: translating
# 2583: translated
# 2584: translating
# 2584: translated
# 2585: translating
# 2585: translated
# 2586: translating
# 2586: translated
# 2587: translating
# 2587: translated
# 2588: translating
# 2588: translated
# 2589: translating
# 2589: translated
# 2590: translating
# 2590: translated
# 2591: translating
# 2591: translated
# 2592: translating
# 2592: translated
# 2593: translating
# 2593: translated
# 2594: translating
# 2594: translated
# 2595: translating
# 2595: translated
# 2596: translating
# 2596: translated
# 2597: translating
# 2597: translated
# 2598: translating
# 2598: translated
# 2599: translating
# 2599: translated
# 2600: translating
# 2600: translated
# 2601: translating
# 2601: translated
# 2602: translating
# 2602: translated
# 2603: translating
# 2603: translated
# 2604: translating
# 2604: translated
# 2605: translating
# 2605: translated
# 2606: translating
# 2606: translated
# 2607: translating
# 2607: translated
# 2608: translating
# 2608: translated
# 2609: translating
# 2609: translated
# 2610: translating
# 2610: translated
# 2611: translating
# 2611: translated
# 2612: translating
# 2612: translated
# 2613: translating
# 2613: translated
# 2614: translating
# 2614: translated
# 2615: translating
# 2615: translated
# 2616: translating
# 2616: translated
# 2617: translating
# 2617: translated
# 2618: translating
# 2618: translated
# 2619: translating
# 2619: translated
# 2620: translating
# 2620: translated
# 2621: translating
# 2621: translated
# 2622: translating
# 2622: translated
# 2623: translating
# 2623: translated
# 2624: translating
# 2624: translated
# 2625: translating
# 2625: translated
# 2626: translating
# 2626: translated
# 2627: translating
# 2627: translated
# 2628: translating
# 2628: translated
# 2629: translating
# 2629: translated
# 2630: translating
# 2630: translated
# 2631: translating
# 2631: translated
# 2632: translating
# 2632: translated
# 2633: translating
# 2633: translated
# 2634: translating
# 2634: translated
# 2635: translating
# 2635: translated
# 2636: translating
# 2636: translated
# 2637: translating
# 2637: translated
# 2638: translating
# 2638: translated
# 2639: translating
# 2639: translated
# 2640: translating
# 2640: translated
# 2641: translating
# 2641: translated
# 2642: translating
# 2642: translated
# 2643: translating
# 2643: translated
# 2644: translating
# 2644: translated
# 2645: translating
# 2645: translated
# 2646: translating
# 2646: translated
# 2647: translating
# 2647: translated
# 2648: translating
# 2648: translated
# 2649: translating
# 2649: translated
# 2650: translating
# 2650: translated
# 2651: translating
# 2651: translated
# 2652: translating
# 2652: translated
# 2653: translating
# 2653: translated
# 2654: translating
# 2654: translated
# 2655: translating
# 2655: translated
# 2656: translating
# 2656: translated
# 2657: translating
# 2657: translated
# 2658: translating
# 2658: translated
# 2659: translating
# 2659: translated
# 2660: translating
# 2660: translated
# 2661: translating
# 2661: translated
# 2662: translating
# 2662: translated
# 2663: translating
# 2663: translated
# 2664: translating
# 2664: translated
# 2665: translating
# 2665: translated
# 2666: translating
# 2666: translated
# 2667: translating
# 2667: translated
# 2668: translating
# 2668: translated
# 2669: translating
# 2669: translated
# 2670: translating
# 2670: translated
# 2671: translating
# 2671: translated
# 2672: translating
# 2672: translated
# 2673: translating
# 2673: translated
# 2674: translating
# 2674: translated
# 2675: translating
# 2675: translated
# 2676: translating
# 2676: translated
# 2677: translating
# 2677: translated
# 2678: translating
# 2678: translated
# 2679: translating
# 2679: translated
# 2680: translating
# 2680: translated
# 2681: translating
# 2681: translated
# 2682: translating
# 2682: translated
# 2683: translating
# 2683: translated
# 2684: translating
# 2684: translated
# 2685: translating
# 2685: translated
# 2686: translating
# 2686: translated
# 2687: translating
# 2687: translated
# 2688: translating
# 2688: translated
# 2689: translating
# 2689: translated
# 2690: translating
# 2690: translated
# 2691: translating
# 2691: translated
# 2692: translating
# 2692: translated
# 2693: translating
# 2693: translated
# 2694: translating
# 2694: translated
# 2695: translating
# 2695: translated
# 2696: translating
# 2696: translated
# 2697: translating
# 2697: translated
# 2698: translating
# 2698: translated
# 2699: translating
# 2699: translated
# 2700: translating
# 2700: translated
# 2701: translating
# 2701: translated
# 2702: translating
# 2702: translated
# 2703: translating
# 2703: translated
# 2704: translating
# 2704: translated
# 2705: translating
# 2705: translated
# 2706: translating
# 2706: translated
# 2707: translating
# 2707: translated
# 2708: translating
# 2708: translated
# 2709: translating
# 2709: translated
# 2710: translating
# 2710: translated
# 2711: translating
# 2711: translated
# 2712: translating
# 2712: translated
# 2713: translating
# 2713: translated
# 2714: translating
# 2714: translated
# 2715: translating
# 2715: translated
# 2716: translating
# 2716: translated
# 2717: translating
# 2717: translated
# 2718: translating
# 2718: translated
# 2719: translating
# 2719: translated
# 2720: translating
# 2720: translated
# 2721: translating
# 2721: translated
# 2722: translating
# 2722: translated
# 2723: translating
# 2723: translated
# 2724: translating
# 2724: translated
# 2725: translating
# 2725: translated
# 2726: translating
# 2726: translated
# 2727: translating
# 2727: translated
# 2728: translating
# 2728: translated
# 2729: translating
# 2729: translated
# 2730: translating
# 2730: translated
# 2731: translating
# 2731: translated
# 2732: translating
# 2732: translated
# 2733: translating
# 2733: translated
# 2734: translating
# 2734: translated
# 2735: translating
# 2735: translated
# 2736: translating
# 2736: translated
# 2737: translating
# 2737: translated
# 2738: translating
# 2738: translated
# 2739: translating
# 2739: translated
# 2740: translating
# 2740: translated
# 2741: translating
# 2741: translated
# 2742: translating
# 2742: translated
# 2743: translating
# 2743: translated
# 2744: translating
# 2744: translated
# 2745: translating
# 2745: translated
# 2746: translating
# 2746: translated
# 2747: translating
# 2747: translated
# 2748: translating
# 2748: translated
# 2749: translating
# 2749: translated
# 2750: translating
# 2750: translated
# 2751: translating
# 2751: translated
# 2752: translating
# 2752: translated
# 2753: translating
# 2753: translated
# 2754: translating
# 2754: translated
# 2755: translating
# 2755: translated
# 2756: translating
# 2756: translated
# 2757: translating
# 2757: translated
# 2758: translating
# 2758: translated
# 2759: translating
# 2759: translated
# 2760: translating
# 2760: translated
# 2761: translating
# 2761: translated
# 2762: translating
# 2762: translated
# 2763: translating
# 2763: translated
# 2764: translating
# 2764: translated
# 2765: translating
# 2765: translated
# 2766: translating
# 2766: translated
# 2767: translating
# 2767: translated
# 2768: translating
# 2768: translated
# 2769: translating
# 2769: translated
# 2770: translating
# 2770: translated
# 2771: translating
# 2771: translated
# 2772: translating
# 2772: translated
# 2773: translating
# 2773: translated
# 2774: translating
# 2774: translated
# 2775: translating
# 2775: translated
# 2776: translating
# 2776: translated
# 2777: translating
# 2777: translated
# 2778: translating
# 2778: translated
# 2779: translating
# 2779: translated
# 2780: translating
# 2780: translated
# 2781: translating
# 2781: translated
# 2782: translating
# 2782: translated
# 2783: translating
# 2783: translated
# 2784: translating
# 2784: translated
# 2785: translating
# 2785: translated
# 2786: translating
# 2786: translated
# 2787: translating
# 2787: translated
# 2788: translating
# 2788: translated
# 2789: translating
# 2789: translated
# 2790: translating
# 2790: translated
# 2791: translating
# 2791: translated
# 2792: translating
# 2792: translated
# 2793: translating
# 2793: translated
# 2794: translating
# 2794: translated
# 2795: translating
# 2795: translated
# 2796: translating
# 2796: translated
# 2797: translating
# 2797: translated
# 2798: translating
# 2798: translated
# 2799: translating
# 2799: translated
# 2800: translating
# 2800: translated
# 2801: translating
# 2801: translated
# 2802: translating
# 2802: translated
# 2803: translating
# 2803: translated
# 2804: translating
# 2804: translated
# 2805: translating
# 2805: translated
# 2806: translating
# 2806: translated
# 2807: translating
# 2807: translated
# 2808: translating
# 2808: translated
# 2809: translating
# 2809: translated
# 2810: translating
# 2810: translated
# 2811: translating
# 2811: translated
# 2812: translating
# 2812: translated
# 2813: translating
# 2813: translated
# 2814: translating
# 2814: translated
# 2815: translating
# 2815: translated
# 2816: translating
# 2816: translated
# 2817: translating
# 2817: translated
# 2818: translating
# 2818: translated
# 2819: translating
# 2819: translated
# 2820: translating
# 2820: translated
# 2821: translating
# 2821: translated
# 2822: translating
# 2822: translated
# 2823: translating
# 2823: translated
# 2824: translating
# 2824: translated
# 2825: translating
# 2825: translated
# 2826: translating
# 2826: translated
# 2827: translating
# 2827: translated
# 2828: translating
# 2828: translated
# 2829: translating
# 2829: translated
# 2830: translating
# 2830: translated
# 2831: translating
# 2831: translated
# 2832: translating
# 2832: translated
# 2833: translating
# 2833: translated
# 2834: translating
# 2834: translated
# 2835: translating
# 2835: translated
# 2836: translating
# 2836: translated
# 2837: translating
# 2837: translated
# 2838: translating
# 2838: translated
# 2839: translating
# 2839: translated
# 2840: translating
# 2840: translated
# 2841: translating
# 2841: translated
# 2842: translating
# 2842: translated
# 2843: translating
# 2843: translated
# 2844: translating
# 2844: translated
# 2845: translating
# 2845: translated
# 2846: translating
# 2846: translated
# 2847: translating
# 2847: translated
# 2848: translating
# 2848: translated
# 2849: translating
# 2849: translated
# 2850: translating
# 2850: translated
# 2851: translating
# 2851: translated
# 2852: translating
# 2852: translated
# 2853: translating
# 2853: translated
# 2854: translating
# 2854: translated
# 2855: translating
# 2855: translated
# 2856: translating
# 2856: translated
# 2857: translating
# 2857: translated
# 2858: translating
# 2858: translated
# 2859: translating
# 2859: translated
# 2860: translating
# 2860: translated
# 2861: translating
# 2861: translated
# 2862: translating
# 2862: translated
# 2863: translating
# 2863: translated
# 2864: translating
# 2864: translated
# 2865: translating
# 2865: translated
# 2866: translating
# 2866: translated
# 2867: translating
# 2867: translated
# 2868: translating
# 2868: translated
# 2869: translating
# 2869: translated
# 2870: translating
# 2870: translated
# 2871: translating
# 2871: translated
# 2872: translating
# 2872: translated
# 2873: translating
# 2873: translated
# 2874: translating
# 2874: translated
# 2875: translating
# 2875: translated
# 2876: translating
# 2876: translated
# 2877: translating
# 2877: translated
# 2878: translating
# 2878: translated
# 2879: translating
# 2879: translated
# 2880: translating
# 2880: translated
# 2881: translating
# 2881: translated
# 2882: translating
# 2882: translated
# 2883: translating
# 2883: translated
# 2884: translating
# 2884: translated
# 2885: translating
# 2885: translated
# 2886: translating
# 2886: translated
# 2887: translating
# 2887: translated
# 2888: translating
# 2888: translated
# 2889: translating
# 2889: translated
# 2890: translating
# 2890: translated
# 2891: translating
# 2891: translated
# 2892: translating
# 2892: translated
# 2893: translating
# 2893: translated
# 2894: translating
# 2894: translated
# 2895: translating
# 2895: translated
# 2896: translating
# 2896: translated
# 2897: translating
# 2897: translated
# 2898: translating
# 2898: translated
# 2899: translating
# 2899: translated
# 2900: translating
# 2900: translated
# 2901: translating
# 2901: translated
# 2902: translating
# 2902: translated
# 2903: translating
# 2903: translated
# 2904: translating
# 2904: translated
# 2905: translating
# 2905: translated
# 2906: translating
# 2906: translated
# 2907: translating
# 2907: translated
# 2908: translating
# 2908: translated
# 2909: translating
# 2909: translated
# 2910: translating
# 2910: translated
# 2911: translating
# 2911: translated
# 2912: translating
# 2912: translated
# 2913: translating
# 2913: translated
# 2914: translating
# 2914: translated
# 2915: translating
# 2915: translated
# 2916: translating
# 2916: translated
# 2917: translating
# 2917: translated
# 2918: translating
# 2918: translated
# 2919: translating
# 2919: translated
# 2920: translating
# 2920: translated
# 2921: translating
# 2921: translated
# 2922: translating
# 2922: translated
# 2923: translating
# 2923: translated
# 2924: translating
# 2924: translated
# 2925: translating
# 2925: translated
# 2926: translating
# 2926: translated
# 2927: translating
# 2927: translated
# 2928: translating
# 2928: translated
# 2929: translating
# 2929: translated
# 2930: translating
# 2930: translated
# 2931: translating
# 2931: translated
# 2932: translating
# 2932: translated
# 2933: translating
# 2933: translated
# 2934: translating
# 2934: translated
# 2935: translating
# 2935: translated
# 2936: translating
# 2936: translated
# 2937: translating
# 2937: translated
# 2938: translating
# 2938: translated
# 2939: translating
# 2939: translated
# 2940: translating
# 2940: translated
# 2941: translating
# 2941: translated
# 2942: translating
# 2942: translated
# 2943: translating
# 2943: translated
# 2944: translating
# 2944: translated
# 2945: translating
# 2945: translated
# 2946: translating
# 2946: translated
# 2947: translating
# 2947: translated
# 2948: translating
# 2948: translated
# 2949: translating
# 2949: translated
# 2950: translating
# 2950: translated
# 2951: translating
# 2951: translated
# 2952: translating
# 2952: translated
# 2953: translating
# 2953: translated
# 2954: translating
# 2954: translated
# 2955: translating
# 2955: translated
# 2956: translating
# 2956: translated
# 2957: translating
# 2957: translated
# 2958: translating
# 2958: translated
# 2959: translating
# 2959: translated
# 2960: translating
# 2960: translated
# 2961: translating
# 2961: translated
# 2962: translating
# 2962: translated
# 2963: translating
# 2963: translated
# 2964: translating
# 2964: translated
# 2965: translating
# 2965: translated
# 2966: translating
# 2966: translated
# 2967: translating
# 2967: translated
# 2968: translating
# 2968: translated
# 2969: translating
# 2969: translated
# 2970: translating
# 2970: translated
# 2971: translating
# 2971: translated
# 2972: translating
# 2972: translated
# 2973: translating
# 2973: translated
# 2974: translating
# 2974: translated
# 2975: translating
# 2975: translated
# 2976: translating
# 2976: translated
# 2977: translating
# 2977: translated
# 2978: translating
# 2978: translated
# 2979: translating
# 2979: translated
# 2980: translating
# 2980: translated
# 2981: translating
# 2981: translated
# 2982: translating
# 2982: translated
# 2983: translating
# 2983: translated
# 2984: translating
# 2984: translated
# 2985: translating
# 2985: translated
# 2986: translating
# 2986: translated
# 2987: translating
# 2987: translated
# 2988: translating
# 2988: translated
# 2989: translating
# 2989: translated
# 2990: translating
# 2990: translated
# 2991: translating
# 2991: translated
# 2992: translating
# 2992: translated
# 2993: translating
# 2993: translated
# 2994: translating
# 2994: translated
# 2995: translating
# 2995: translated
# 2996: translating
# 2996: translated
# 2997: translating
# 2997: translated
# 2998: translating
# 2998: translated
# 2999: translating
# 2999: translated
# 3000: translating
# 3000: translated
# 3001: translating
# 3001: translated
# 3002: translating
# 3002: translated
# 3003: translating
# 3003: translated
# 3004: translating
# 3004: translated
# 3005: translating
# 3005: translated
# 3006: translating
# 3006: translated
# 3007: translating
# 3007: translated
# 3008: translating
# 3008: translated
# 3009: translating
# 3009: translated
# 3010: translating
# 3010: translated
# 3011: translating
# 3011: translated
# 3012: translating
# 3012: translated
# 3013: translating
# 3013: translated
# 3014: translating
# 3014: translated
# 3015: translating
# 3015: translated
# 3016: translating
# 3016: translated
# 3017: translating
# 3017: translated
# 3018: translating
# 3018: translated
# 3019: translating
# 3019: translated
# 3020: translating
# 3020: translated
# 3021: translating
# 3021: translated
# 3022: translating
# 3022: translated
# 3023: translating
# 3023: translated
# 3024: translating
# 3024: translated
# 3025: translating
# 3025: translated
# 3026: translating
# 3026: translated
# 3027: translating
# 3027: translated
# 3028: translating
# 3028: translated
# 3029: translating
# 3029: translated
# 3030: translating
# 3030: translated
# 3031: translating
# 3031: translated
# 3032: translating
# 3032: translated
# 3033: translating
# 3033: translated
# 3034: translating
# 3034: translated
# 3035: translating
# 3035: translated
# 3036: translating
# 3036: translated
# 3037: translating
# 3037: translated
# 3038: translating
# 3038: translated
# 3039: translating
# 3039: translated
# 3040: translating
# 3040: translated
# 3041: translating
# 3041: translated
# 3042: translating
# 3042: translated
# 3043: translating
# 3043: translated
# 3044: translating
# 3044: translated
# 3045: translating
# 3045: translated
# 3046: translating
# 3046: translated
# 3047: translating
# 3047: translated
# 3048: translating
# 3048: translated
# 3049: translating
# 3049: translated
# 3050: translating
# 3050: translated
# 3051: translating
# 3051: translated
# 3052: translating
# 3052: translated
# 3053: translating
# 3053: translated
# 3054: translating
# 3054: translated
# 3055: translating
# 3055: translated
# 3056: translating
# 3056: translated
# 3057: translating
# 3057: translated
# 3058: translating
# 3058: translated
# 3059: translating
# 3059: translated
# 3060: translating
# 3060: translated
# 3061: translating
# 3061: translated
# 3062: translating
# 3062: translated
# 3063: translating
# 3063: translated
# 3064: translating
# 3064: translated
# 3065: translating
# 3065: translated
# 3066: translating
# 3066: translated
# 3067: translating
# 3067: translated
# 3068: translating
# 3068: translated
# 3069: translating
# 3069: translated
# 3070: translating
# 3070: translated
# 3071: translating
# 3071: translated
# 3072: translating
# 3072: translated
# 3073: translating
# 3073: translated
# 3074: translating
# 3074: translated
# 3075: translating
# 3075: translated
# 3076: translating
# 3076: translated
# 3077: translating
# 3077: translated
# 3078: translating
# 3078: translated
# 3079: translating
# 3079: translated
# 3080: translating
# 3080: translated
# 3081: translating
# 3081: translated
# 3082: translating
# 3082: translated
# 3083: translating
# 3083: translated
# 3084: translating
# 3084: translated
# 3085: translating
# 3085: translated
# 3086: translating
# 3086: translated
# 3087: translating
# 3087: translated
# 3088: translating
# 3088: translated
# 3089: translating
# 3089: translated
# 3090: translating
# 3090: translated
# 3091: translating
# 3091: translated
# 3092: translating
# 3092: translated
# 3093: translating
# 3093: translated
# 3094: translating
# 3094: translated
# 3095: translating
# 3095: translated
# 3096: translating
# 3096: translated
# 3097: translating
# 3097: translated
# 3098: translating
# 3098: translated
# 3099: translating
# 3099: translated
# 3100: translating
# 3100: translated
# 3101: translating
# 3101: translated
# 3102: translating
# 3102: translated
# 3103: translating
# 3103: translated
# 3104: translating
# 3104: translated
# 3105: translating
# 3105: translated
# 3106: translating
# 3106: translated
# 3107: translating
# 3107: translated
# 3108: translating
# 3108: translated
# 3109: translating
# 3109: translated
# 3110: translating
# 3110: translated
# 3111: translating
# 3111: translated
# 3112: translating
# 3112: translated
# 3113: translating
# 3113: translated
# 3114: translating
# 3114: translated
# 3115: translating
# 3115: translated
# 3116: translating
# 3116: translated
# 3117: translating
# 3117: translated
# 3118: translating
# 3118: translated
# 3119: translating
# 3119: translated
# 3120: translating
# 3120: translated
# 3121: translating
# 3121: translated
# 3122: translating
# 3122: translated
# 3123: translating
# 3123: translated
# 3124: translating
# 3124: translated
# 3125: translating
# 3125: translated
# 3126: translating
# 3126: translated
# 3127: translating
# 3127: translated
# 3128: translating
# 3128: translated
# 3129: translating
# 3129: translated
# 3130: translating
# 3130: translated
# 3131: translating
# 3131: translated
# 3132: translating
# 3132: translated
# 3133: translating
# 3133: translated
# 3134: translating
# 3134: translated
# 3135: translating
# 3135: translated
# 3136: translating
# 3136: translated
# 3137: translating
# 3137: translated
# 3138: translating
# 3138: translated
# 3139: translating
# 3139: translated
# 3140: translating
# 3140: translated
# 3141: translating
# 3141: translated
# 3142: translating
# 3142: translated
# 3143: translating
# 3143: translated
# 3144: translating
# 3144: translated
# 3145: translating
# 3145: translated
# 3146: translating
# 3146: translated
# 3147: translating
# 3147: translated
# 3148: translating
# 3148: translated
# 3149: translating
# 3149: translated
# 3150: translating
# 3150: translated
# 3151: translating
# 3151: translated
# 3152: translating
# 3152: translated
# 3153: translating
# 3153: translated
# 3154: translating
# 3154: translated
# 3155: translating
# 3155: translated
# 3156: translating
# 3156: translated
# 3157: translating
# 3157: translated
# 3158: translating
# 3158: translated
# 3159: translating
# 3159: translated
# 3160: translating
# 3160: translated
# 3161: translating
# 3161: translated
# 3162: translating
# 3162: translated
# 3163: translating
# 3163: translated
# 3164: translating
# 3164: translated
# 3165: translating
# 3165: translated
# 3166: translating
# 3166: translated
# 3167: translating
# 3167: translated
# 3168: translating
# 3168: translated
# 3169: translating
# 3169: translated
# 3170: translating
# 3170: translated
# 3171: translating
# 3171: translated
# 3172: translating
# 3172: translated
# 3173: translating
# 3173: translated
# 3174: translating
# 3174: translated
# 3175: translating
# 3175: translated
# 3176: translating
# 3176: translated
# 3177: translating
# 3177: translated
# 3178: translating
# 3178: translated
# 3179: translating
# 3179: translated
# 3180: translating
# 3180: translated
# 3181: translating
# 3181: translated
# 3182: translating
# 3182: translated
# 3183: translating
# 3183: translated
# 3184: translating
# 3184: translated
# 3185: translating
# 3185: translated
# 3186: translating
# 3186: translated
# 3187: translating
# 3187: translated
# 3188: translating
# 3188: translated
# 3189: translating
# 3189: translated
# 3190: translating
# 3190: translated
# 3191: translating
# 3191: translated
# 3192: translating
# 3192: translated
# 3193: translating
# 3193: translated
# 3194: translating
# 3194: translated
# 3195: translating
# 3195: translated
# 3196: translating
# 3196: translated
# 3197: translating
# 3197: translated
# 3198: translating
# 3198: translated
# 3199: translating
# 3199: translated
# 3200: translating
# 3200: translated
# 3201: translating
# 3201: translated
# 3202: translating
# 3202: translated
# 3203: translating
# 3203: translated
# 3204: translating
# 3204: translated
# 3205: translating
# 3205: translated
# 3206: translating
# 3206: translated
# 3207: translating
# 3207: translated
# 3208: translating
# 3208: translated
# 3209: translating
# 3209: translated
# 3210: translating
# 3210: translated
# 3211: translating
# 3211: translated
# 3212: translating
# 3212: translated
# 3213: translating
# 3213: translated
# 3214: translating
# 3214: translated
# 3215: translating
# 3215: translated
# 3216: translating
# 3216: translated
# 3217: translating
# 3217: translated
# 3218: translating
# 3218: translated
# 3219: translating
# 3219: translated
# 3220: translating
# 3220: translated
# 3221: translating
# 3221: translated
# 3222: translating
# 3222: translated
# 3223: translating
# 3223: translated
# 3224: translating
# 3224: translated
# 3225: translating
# 3225: translated
# 3226: translating
# 3226: translated
# 3227: translating
# 3227: translated
# 3228: translating
# 3228: translated
# 3229: translating
# 3229: translated
# 3230: translating
# 3230: translated
# 3231: translating
# 3231: translated
# 3232: translating
# 3232: translated
# 3233: translating
# 3233: translated
# 3234: translating
# 3234: translated
# 3235: translating
# 3235: translated
# 3236: translating
# 3236: translated
# 3237: translating
# 3237: translated
# 3238: translating
# 3238: translated
# 3239: translating
# 3239: translated
# 3240: translating
# 3240: translated
# 3241: translating
# 3241: translated
# 3242: translating
# 3242: translated
# 3243: translating
# 3243: translated
# 3244: translating
# 3244: translated
# 3245: translating
# 3245: translated
# 3246: translating
# 3246: translated
# 3247: translating
# 3247: translated
# 3248: translating
# 3248: translated
# 3249: translating
# 3249: translated
# 3250: translating
# 3250: translated
# 3251: translating
# 3251: translated
# 3252: translating
# 3252: translated
# 3253: translating
# 3253: translated
# 3254: translating
# 3254: translated
# 3255: translating
# 3255: translated
# 3256: translating
# 3256: translated
# 3257: translating
# 3257: translated
# 3258: translating
# 3258: translated
# 3259: translating
# 3259: translated
# 3260: translating
# 3260: translated
# 3261: translating
# 3261: translated
# 3262: translating
# 3262: translated
# 3263: translating
# 3263: translated
# 3264: translating
# 3264: translated
# 3265: translating
# 3265: translated
# 3266: translating
# 3266: translated
# 3267: translating
# 3267: translated
# 3268: translating
# 3268: translated
# 3269: translating
# 3269: translated
# 3270: translating
# 3270: translated
# 3271: translating
# 3271: translated
# 3272: translating
# 3272: translated
# 3273: translating
# 3273: translated
# 3274: translating
# 3274: translated
# 3275: translating
# 3275: translated
# 3276: translating
# 3276: translated
# 3277: translating
# 3277: translated
# 3278: translating
# 3278: translated
# 3279: translating
# 3279: translated
# 3280: translating
# 3280: translated
# 3281: translating
# 3281: translated
# 3282: translating
# 3282: translated
# 3283: translating
# 3283: translated
# 3284: translating
# 3284: translated
# 3285: translating
# 3285: translated
# 3286: translating
# 3286: translated
# 3287: translating
# 3287: translated
# 3288: translating
# 3288: translated
# 3289: translating
# 3289: translated
# 3290: translating
# 3290: translated

# %%
pd.read_csv('kospi200_2015_2019_translated.csv', encoding='utf-8')
# Out:
#                         File  Start  End  \
# 0     316140_분기보고서 (2019.03)     24  105
# 1     000070_반기보고서 (2018.06)     17   49
# 2     000070_분기보고서 (2018.03)     16   49
# 3     000070_분기보고서 (2018.09)     17   51
# 4     000070_사업보고서 (2017.12)     18   50
# ...                      ...    ...  ...
# 3286  271560_반기보고서 (2017.06)     14   32
# 3287  271560_분기보고서 (2017.09)     14   33
# 3288  000050_반기보고서 (2015.06)     10   27
# 3289  000050_반기보고서 (2016.06)      9   25
# 3290  000050_반기보고서 (2017.06)     10   26
#
#                                      Relevant_Sentences  \
# 0     ['업계의 현황 【국내외 경제 및 금융시장 환경】 (1) 국내외 경제 환경 금융은 ...
# 1     ['업계의 현황 지주회사(持株會社, Holding Company)란 다른 회사의 주...
# 2     ['업계의 현황 지주회사(持株會社, Holding Company)란 다른 회사의 주...
# 3     ['업계의 현황 지주회사(持株會社, Holding Company)란 다른 회사의 주...
# 4     ['업계의 현황 지주회사(持株會社, Holding Company)란 다른 회사의 주...
# ...                                                 ...
# 3286  ['산업의 특성 제과산업은 국내 소비자들의 독특한 기호와 고급과자를 중심으로 한 선...
# 3287  ['산업의 특성 제과산업은 국내 소비자들의 독특한 기호와 고급과자를 중심으로 한 선...
# 3288  ['사업의 개요 (1) 면방직산업 국내 면방직산업은 해방 이후 우리나라의 산업 발전...
# 3289  ['주요 제품, 서비스 등 (1) 면방직산업 국내 면방직산업은 해방 이후 우리나라의...
# 3290  ['주요 제품, 서비스 등 (1) 면방직산업 국내 면방직산업은 해방 이후 우리나라의...
#
#                                              Translated
# 0     Industry Status 【Domestic and foreign economic...
# 1     Status of the industry Holding company (持 株 會 ...
# 2     Status of the industry Holding company (持 株 會 ...
# 3     Status of the industry Holding company (持 株 會 ...
# 4     Status of the industry Holding company (持 株 會 ...
# ...                                                 ...
# 3286  Characteristics of Industry In the confectione...
# 3287  Characteristics of Industry In the confectione...
# 3288  Business Overview (1) Cotton Textile Industry ...
# 3289  Main products, services, etc. (1) Cotton texti...
# 3290  Main Products, Services, etc. (1) Cotton Texti...
#
# [3291 rows x 5 columns]

# %%
df = pd.read_csv('kospi200_2015_2019_translated.csv', encoding='utf-8')

# %%
df_kospi_filing_2015_2019_parsed.to_csv('kospi200_2015_2019_translated.csv', encoding='utf-8', index=False)

# %%
df_kospi_filing_2015_2019_parsed.to_csv('kospi200_2015_2019_translated.csv', encoding='utf-8', index=False)
